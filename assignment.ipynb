# %% [markdown]
# # BioMed: Information Retrieval - BioMedical Information Retrieval System
#
# ---
#
# **Group:**
# - Reyes Castro, Didier Yamil (didier.reyes.castro@alumnos.upm.es)
# - Rodriguez Fernández, Cristina ()
#
# **Course:** BioMedical Informatics - 2025/26
#
# **Institution:** Polytechnic University of Madrid (UPM)
#
# **Date:** November 2026
#
# ---
#
# ## Goal
#
# To develop an Information Retrieval system — specifically, a **binary text classifier** — to identify scientific articles in the PubMed database that are related to a given set of abstracts within a defined research topic. In this case, the focus is on a collection of 1,308 manuscripts containing information on the polyphenol composition of various foods.

# %% [markdown]
# ## Setup and Installation

# %%
# !pip install scikit-learn pandas requests transformers pytorch datasets numpy

# %%
import requests
import time
import torch
import pandas as pd
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer, EarlyStoppingCallback
from datasets import Dataset
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, classification_report

# %% [markdown]
# ## **Task 1:**
#
# Retrieve from PubMed the abstracts associated with each publication in publications.xlsx
#
# (21 minutes with API KEY)

# %%
BASE_URL = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/"
ESEARCH_URL = BASE_URL + "esearch.fcgi"
FETCH_URL = BASE_URL + "efetch.fcgi"
DS_WITH_PMID = 'publications_pmid.csv'
PMID_ABSTRACTS = 'publications_pmid_abstract.csv'
ELSEVIER_SEARCH_URL = "https://api.elsevier.com/content/search/scopus"
ELSEVIER_ABSTRACTS = 'publications_abstract_pubmed_elsevier.csv'

# %%
dataset = pd.read_csv('publications.csv')
dataset
# Out:
#         id                                            authors  \
# 0     1216      Aaby K., Wrolstad R.E., Ekeberg D., Skrede G.
# 1     1052  Abd El Mohsen M.M., Kuhnle G., Rechner A.R., S...
# 2      356                         Abdel-Aal E.-S.M., Hucl P.
# 3      458          Abdel-Aal E.-S. M., Young C., Rabalski I.
# 4      332  Abril M., Negueruela A.I., Perez C., Juan T., ...
# ...    ...                                                ...
# 1303   816             Zielinski H., Kozlowska H., Lewczuk B.
# 1304   497  Zielinski H., Michalska A., Piskula M.K., Kozl...
# 1305   743            Zimmermann R., Bauermann U., Morales F.
# 1306   203                           Zuo Y., Wang C., Zhan J.
# 1307   462  Zupfer J.M., Churchill K.E., Rasmusson D.C., F...
#
#      year_of_publication                                              title  \
# 0                   2007  Polyphenol composition and antioxidant activit...
# 1                   2002  Uptake and metabolism of epicatechin and its a...
# 2                   2003  Composition and stability of anthocyanins in b...
# 3                   2006  Anthocyanin composition in black, blue, pink, ...
# 4                   2005  Preliminary study of resveratrol content in Ar...
# ...                  ...                                                ...
# 1303                2001  Bioactive compounds in the cereal grains befor...
# 1304                2006  Antioxidants in thermally treated buckwheat gr...
# 1305                2006  Effects of growing site and nitrogen fertiliza...
# 1306                2002  Separation, characterization and quantitation ...
# 1307                1998  Variation in ferulic acid concentration among ...
#
#             abbreviation                                       journal_name  \
# 0              AABY 2007         Journal of Agricultural and Food Chemistry
# 1     ABD EL MOHSEN 2002                                Free Radic Biol Med
# 2         ABDEL-AAL 2003         Journal of Agricultural and Food Chemistry
# 3         ABDEL-AAL 2006         Journal of Agricultural and Food Chemistry
# 4                 Apr-05                                     Food Chemistry
# ...                  ...                                                ...
# 1303      ZIELINSKI 2001  Innovative Food Science and Emerging Technologies
# 1304      ZIELINSKI 2006              Molecular Nutrition and Food Research
# 1305     ZIMMERMANN 2006     Journal of the Science of Food and Agriculture
# 1306            ZUO 2002         Journal of Agricultural and Food Chemistry
# 1307         ZUPFER 1998         Journal of Agricultural and Food Chemistry
#
#      journal_volume journal_issue      pages               created_at  \
# 0                55            13  5156-5166  2012-12-01 22:21:08 UTC
# 1                33            12   1693-702  2015-04-13 21:45:29 UTC
# 2                51           NaN  2174-2180  2015-04-13 21:45:25 UTC
# 3                54           NaN  4696-4704  2006-04-09 12:07:36 UTC
# 4                92             4    729-736  2015-04-13 21:45:25 UTC
# ...             ...           ...        ...                      ...
# 1303              2           NaN    159-169  2015-04-13 21:45:28 UTC
# 1304             50           NaN    824-832  2015-04-13 21:45:26 UTC
# 1305             86           NaN    415-419  2015-04-13 21:45:27 UTC
# 1306             50            13  3789-3794  2015-04-13 21:45:24 UTC
# 1307             46           NaN  1350-1354  2015-04-13 21:45:25 UTC
#
#                    updated_at
# 0      2015-04-14 04:25:30 UTC
# 1     2015-04-14 04:25:30 UTC
# 2     2015-04-14 04:25:30 UTC
# 3     2015-04-14 04:25:31 UTC
# 4     2015-04-13 21:45:25 UTC
# ...                             ...
# 1303  2015-04-13 21:45:28 UTC
# 1304  2015-04-14 13:51:47 UTC
# 1305  2015-04-13 21:45:27 UTC
# 1306  2015-04-14 13:51:48 UTC
# 1307  2015-04-13 21:45:25 UTC
#
# [1308 rows x 11 columns]

# %%
# Step 1: Search for the PMID of the articles by title
def search_pmid(article):

    title = article['title']
    params = {
        "db": "pubmed",
        "term": f"{title}",
        "retmode": "json",
        "field": "title"
    }

    try:

        # Trying to find the PMID
        response = requests.get(ESEARCH_URL, params=params)
        response.raise_for_status()
        data = response.json()

        if len(data["esearchresult"]["idlist"]) >= 1:
            pmid = data['esearchresult']['idlist'][0]
            print(f"> Found PMID for article: {pmid}")
            return pmid

        print(f"> No PMID found for article.")
        return None

    except requests.exceptions.RequestException as e:
        print(f"> ERROR during request for article: {e}")
        return None

ds_pmid = dataset.copy()
for idx, article in ds_pmid.iterrows():
    print(f"[{idx + 1}/{len(ds_pmid)}] Searching PMID for: {article['title']}")
    pmid = search_pmid(article)
    ds_pmid.at[idx, 'pmid'] = pmid

ds_pmid.to_csv(DS_WITH_PMID, index=False)
# Out:
# [1/1308] Searching PMID for: Polyphenol composition and antioxidant activity in strawberry purees  impact of achene level and storage
# > ERROR during request for article: HTTPSConnectionPool(host='eutils.ncbi.nlm.nih.gov', port=443): Max retries exceeded with url: /entrez/eutils/esearch.fcgi?db=pubmed&term=Polyphenol+composition+and+antioxidant+activity+in+strawberry+purees++impact+of+achene+level+and+storage&retmode=json&field=title (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7dd4689ad8b0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# [2/1308] Searching PMID for: Uptake and metabolism of epicatechin and its access to the brain after oral ingestion
# > ERROR during request for article: HTTPSConnectionPool(host='eutils.ncbi.nlm.nih.gov', port=443): Max retries exceeded with url: /entrez/eutils/esearch.fcgi?db=pubmed&term=Uptake+and+metabolism+of+epicatechin+and+its+access+to+the+brain+after+oral+ingestion&retmode=json&field=title (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7dd4689e3080>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# [3/1308] Searching PMID for: Composition and stability of anthocyanins in blue-grained wheat
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [4/1308] Searching PMID for: Anthocyanin composition in black, blue, pink, purple, and red cereal grains
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [5/1308] Searching PMID for: Preliminary study of resveratrol content in Aragon red and rose wines
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [6/1308] Searching PMID for: HPLC method for the quantification of procyanidins in cocoa and chocolate samples and correlation to total antioxidant capacity
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [7/1308] Searching PMID for: Enhancement of total phenolics and antioxidant properties of some tropical green leafy vegetables by steam cooking
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [8/1308] Searching PMID for: Urinary excretion of lignans and isoflavonoid phytoestrogens in Japanese men and women consuming a traditional Japanese diet
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [9/1308] Searching PMID for: Antioxidant activity of grains
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [10/1308] Searching PMID for: Phytochemicals and antioxidant activity of milled fractions of different wheat varieties
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [11/1308] Searching PMID for: Correlation of tocopherol, tocotrienol, gamma-oryzanol and total polyphenol content in rice bran with different antioxidant capacity assays
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [12/1308] Searching PMID for: Evaluation of Phenolic Profile and Antioxidant Properties of Pardina Lentil As Affected by Industrial Dehydration
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [13/1308] Searching PMID for: High-Performance Liquid-Chromatography of Selected Phenolic-Compounds in Olive Oils
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [14/1308] Searching PMID for: Functional attributes of soybean seeds and products, with reference to isoflavone content and antioxidant activity
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [15/1308] Searching PMID for: Comparison of antioxidant activity, anthocyanins, carotenoids, and phenolics of three native fresh and sun-dried date (Phoenix dactylifera L.) varieties grown in Oman
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [16/1308] Searching PMID for: Compositional and functional characteristics of dates, syrups, and their by-products
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [17/1308] Searching PMID for: Nutritional composition of chickpea (Cicer arietinum L.) as affected by  microwave cooking and other traditional cooking methods
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [18/1308] Searching PMID for: Characterization and antioxidant activity of nocino liqueur
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [19/1308] Searching PMID for: Comparison of volatiles, phenolics, sugars, antioxidant vitamins, and sensory quality of different colored carrot varieties
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [20/1308] Searching PMID for: Effects of Roasting on Taste-Active Compounds of TurkisH Hazelnut Varieties (Corylus avellana L.)
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [21/1308] Searching PMID for: Anthocyanins characterization of 15 Iranian pomegranate (Punica granatum L.) varieties and their variation after cold storage and pasteurization
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [22/1308] Searching PMID for: Effects of extrusion and traditional processing methods on antinutrients and in vitro digestibility of protein and starch in faba and kidney beans
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [23/1308] Searching PMID for: Study of the antioxidant power of brandies and vinegars derived from Sherry wines and correlation with their content in polyphenols
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [24/1308] Searching PMID for: Development of a rapid method based on solid-phase extraction and liquid chromatography with ultraviolet absorbance detection for the determination of polyphenols in alcohol-free beers
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [25/1308] Searching PMID for: Determination of polyphenolic profiles of Basque cider apple varieties using accelerated solvent extraction
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [26/1308] Searching PMID for: Polyphenolic profiles of Basque cider apple cultivars and their technological properties
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [27/1308] Searching PMID for: Classification of apple fruits according to their maturity state by the pattern recognition analysis of their polyphenolic compositions
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [28/1308] Searching PMID for: Influence of processing and pasteurization on color values and total phenolic compounds of pomegranate juice
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [29/1308] Searching PMID for: Influence of jam processing on the radical scavenging activity and phenolic content in berries
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [30/1308] Searching PMID for: Polyphenolics extracts from legume seeds: correlations between total antioxidant activity, total phenolics content, tannins content and astringency
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [31/1308] Searching PMID for: Flavanone absorption after naringin, hesperidin, and citrus administration
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [32/1308] Searching PMID for: Effect of different blanching times on antioxidant properties in selected cruciferous vegetables
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [33/1308] Searching PMID for: Phenolic composition and browning susceptibility of various apple cultivars at maturity
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [34/1308] Searching PMID for: Phenolic composition and browning susceptibility of various apple and pear cultivars at maturity
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [35/1308] Searching PMID for: Influence of cultivar, maturity stage, and storage conditions on phenolic composition and enzymatic browning of pear fruits
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [36/1308] Searching PMID for: Ellagic acid, vitamin C, and total phenolic contents and radical scavenging capacity affected by freezing and frozen storage in raspberry fruit
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [37/1308] Searching PMID for: Frozen storage effects on anthocyanins and volatile compounds of raspberry fruit
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [38/1308] Searching PMID for: Potential antioxidants in beer assessed by ESR spin trapping
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [39/1308] Searching PMID for: Influence of cooking process on phenolic marker compounds of vegetables
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [40/1308] Searching PMID for: Preliminary study of flavonols in port wine grape varieties
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [41/1308] Searching PMID for: Ferulic acid dehydrodimers in Rye
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [42/1308] Searching PMID for: Content of phenolic acids and ferulic acid dehydrodimers in 17 rye (Secale cerealeL.) varieties
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [43/1308] Searching PMID for: Flavanol and flavonol contents of cocoa powder products: Influence of the manufacturing process
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [44/1308] Searching PMID for: Effect of cooking on total phenols, flavonoids and antioxidant activity in spices of Indian culinary
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [45/1308] Searching PMID for: Environmental and genetic variation of phenolic compounds in red raspberry
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [46/1308] Searching PMID for: Effect of Various Compounds on Virgin Olive Oil Stability Measured by Rancimat
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [47/1308] Searching PMID for: Comparison of antimutagenic activity of phenolic compounds in newly harvested and stored common beans Phaseolus vulgaris against aflatoxin B1
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [48/1308] Searching PMID for: Flavonoids in vegetable foods commonly consumed in Brazil and estimated ingestion by the Brazilian population
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [49/1308] Searching PMID for: Phenolic fingerprint of peppermint leaves
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [50/1308] Searching PMID for: Evaluation of the antioxidant capacity of blood orange juices as influenced by constituents, concentration process and storage
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [51/1308] Searching PMID for: Correlation of pigment and flavanol content with antioxidant properties in selected aged regional wines from Greece
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [52/1308] Searching PMID for: Effect of irrigation applied to olive trees (Olea europaea L.) on phenolic compound transfer during olive oil extraction
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [53/1308] Searching PMID for: Transfer of phenolic compounds during olive oil extraction in relation to ripening stage of the fruit
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [54/1308] Searching PMID for: Chocolate as a source of tea flavonoids
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [55/1308] Searching PMID for: Catechin Contents of Foods Commonly Consumed in The Netherlands. 1. Fruits, Vegetables, Staple Foods, and Processed Foods
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [56/1308] Searching PMID for: Catechin Contents of Foods Commonly Consumed in The Netherlands. 2. Tea, Wine, Fruit juices and chocolate milk
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [57/1308] Searching PMID for: Processing-induced changes in total phenolics and procyanidins in clingstone peaches
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [58/1308] Searching PMID for: Comparison of the total phenolic and ascorbic acid content of freeze-dried and air-dried marionberry, strawberry, and corn grown using conventional, organic, and sustainable agricultural practices
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [59/1308] Searching PMID for: Inhibition of cancer growth by resveratrol is related to its low bioavailability
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [60/1308] Searching PMID for: Chemical structure of flavonoid compounds in wheat (Triticum aestivum L.) flour that contribute to the yellow colour of Asian alkaline noodles
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [61/1308] Searching PMID for: Factors affecting the caffeine and polyphenol contents of black and green tea infusions
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [62/1308] Searching PMID for: Separation of flavanone-7-O-glycoside diastereomers and analysis in citrus juices by multidimensional liquid chromatography coupled with mass spectrometry
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [63/1308] Searching PMID for: Processing of sorghum (Sorghum bicolor) and sorghum products alters procyanidin oligomer and polymer distribution and content
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [64/1308] Searching PMID for: Cocoa powder enhances the level of antioxidative activity in rat plasma
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [65/1308] Searching PMID for: Absorption and urinary excretion of (-)-epicatechin after administration of different levels of cocoa powder or (-)-epicatechin in rats
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [66/1308] Searching PMID for: In vivo comparison of the bioavailability of (+)-catechin, (-)-epicatechin and their mixture in orally administered rats
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [67/1308] Searching PMID for: Absorption and urinary excretion of procyanidin B2 [epicatechin-(4beta-8)-epicatechin] in rats
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [68/1308] Searching PMID for: Orally administered rosmarinic acid is present as the conjugated and/or methylated forms in plasma, and is degraded and metabolized to conjugated forms of caffeic acid, ferulic acid and m-coumaric aci
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [69/1308] Searching PMID for: Absorption, metabolism, degradation and urinary excretion of rosmarinic acid after intake of Perilla frutescens extract in humans
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [70/1308] Searching PMID for: Continuous intake of polyphenolic compounds containing cocoa powder reduces LDL oxidative susceptibility and has beneficial effects on plasma HDL-cholesterol concentrations in humans
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [71/1308] Searching PMID for: Analytical characteristics of virgin olive oils from two new varieties obtained by controlled crossing on Meski variety
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [72/1308] Searching PMID for: Total phenol, flavonoid, proanthocyanidin and vitamin C levels and antioxidant activities of Mauritian vegetables
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [73/1308] Searching PMID for: Isolation and identification of urinary metabolites of kakkalide in rats
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [74/1308] Searching PMID for: Changes in Phenolic Content and Antioxidant Activity of Italian Extra-Virgin Olive Oils during Storage
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [75/1308] Searching PMID for: Chemical evaluation of some important varieties of onion (Allium cepa L.)
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [76/1308] Searching PMID for: Comparison of various extraction techniques for isolation and determination of isoflavonoids in plants
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [77/1308] Searching PMID for: Antioxidant and free radical scavenging activities of some leafy vegetables
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [78/1308] Searching PMID for: Possible role of plant phenolics in the production of trichothecenes by Fusarium graminearum strains on different fractions of maize kernels
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [79/1308] Searching PMID for: Strawberry juice colour: a study of the quantitative and qualitative pigment composition of juices from 39 genotypes
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [80/1308] Searching PMID for: Black currant polyphenols: Their storage stability and microencapsulation
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [81/1308] Searching PMID for: Antioxidant activity of tocopherols and phenolic compounds of virgin olive oil
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [82/1308] Searching PMID for: Changes in total phenolic and flavonoid contents of rowanberry fruit during postharvest storage
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [83/1308] Searching PMID for: Evaluation of phenolic content and antioxidant activity of Iranian caraway in comparison with clove and BHT using model systems and vegetable oil
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [84/1308] Searching PMID for: Preliminary screening of antioxidant activity of some plant extracts in rapeseed oil
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [85/1308] Searching PMID for: Total Phenolic, Phenolic Acid, Anthocyanin, Flavan-3-ol, and flavonol profile and antioxidant properties of pinto and black
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [86/1308] Searching PMID for: Comparison of polyphenols and aroma in red wines from Portuguese mainland versus Azores Islands
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [87/1308] Searching PMID for: Analysis of mixture of catechins, flavones, flavanones, flavonols, and anthocyanidins by RP-HPLC
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [88/1308] Searching PMID for: Phenolic constituents levels in cv. Agria potato under microwave processing
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [89/1308] Searching PMID for: Physicochemical and nutritional characteristics of blueberry juice after high pressure processing
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [90/1308] Searching PMID for: Evaluation of quality changes of blueberry juice during refrigerated storage after high-pressure and pulsed electric fields processing
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [91/1308] Searching PMID for: Applications of LC-MS in the study of the uptake, distribution, metabolism and excretion of bioactive polyphenols from dietary supplements
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [92/1308] Searching PMID for: Changes in phenolic compounds and browning during biological aging of sherry-type wine
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [93/1308] Searching PMID for: Radioimmunoassay for the quantitative determination of hesperidin and analysis of its distribution in citrus sinensis
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [94/1308] Searching PMID for: Changes in phenolic compounds in lentils (Lens culinaris) during germination and fermentation
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [95/1308] Searching PMID for: Phenolics and related substances in alcohol-free beers
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [96/1308] Searching PMID for: Determination of carnosic acid and rosmarinic acid in sage by capillary electrophoresis
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [97/1308] Searching PMID for: Evaluation of fruit quality in peach and apricot
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [98/1308] Searching PMID for: The occurrence of the stilbene piceatannol in grapes
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [99/1308] Searching PMID for: Disposition and biotransformation of the estrogenic isoflavone daidzein in rats
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [100/1308] Searching PMID for: Development of a sensitive and specific solid phase extraction--gas chromatography-tandem mass spectrometry method for the determination of elenolic acid, hydroxytyrosol, and tyrosol in rat urine
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [101/1308] Searching PMID for: Simultaneous quantification of oleuropein and its metabolites in rat plasma by liquid chromatography electrospray ionization tandem mass spectrometry
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [102/1308] Searching PMID for: Microwave-assisted extraction of the main phenolic compounds in flaxseed
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [103/1308] Searching PMID for: Determination of green and black tea composition by capillary electrophoresis
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [104/1308] Searching PMID for: Linear furanocoumarins and graveolone from the common herb parsley
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [105/1308] Searching PMID for: Determination of phenolic constituents in citrus juices: Method of high performance liquid chromatography
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [106/1308] Searching PMID for: Resveratrol content of Tunisian wines
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [107/1308] Searching PMID for: (+)-Catechin in human plasma after ingestion of a single serving of reconstituted red wine
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [108/1308] Searching PMID for: Determination of tannic acid in beer by high performance liquid chromatography
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [109/1308] Searching PMID for: HPLC analysis of chlorogenic acid lactones in roasted coffee
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [110/1308] Searching PMID for: Polyphenols, anthocyanins, ascorbic acid, and radical scavenging activity of Rubus, Ribes, and Aronia
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [111/1308] Searching PMID for: Flavonoids in baby spinach (Spinacia oleracea L.): changes during plant growth and storage
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [112/1308] Searching PMID for: NLG Overview Report. Nutrient Losses and Gains in the preparation of foods
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [113/1308] Searching PMID for: Phenolic compounds and kernel characteristics of Zimbabwean sorghums
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [114/1308] Searching PMID for: Phenolics in white free run juices and wines from Penedes by high-performance liquid chromatography: changes during vinification
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [115/1308] Searching PMID for: Biophenolic components of olives
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [116/1308] Searching PMID for: The occurrence in olive oil of a new class of phenolic compounds: hydroxy-isochromans
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [117/1308] Searching PMID for: Analysis by liquid chromatography-tandem mass spectrometry of biophenolic compounds in olives and vegetation waters, part 1
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [118/1308] Searching PMID for: Analysis by liquid chromatography-tandem mass spectrometry of biophenolic compounds in virgin olive oil, part II
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [119/1308] Searching PMID for: Identification by HPLC-DAD and HPLC-MS analyses and quantification of constituents of fennel teas and decoctions
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [120/1308] Searching PMID for: Distribution of quercetin and kaempferol in lettuce, kale, chive, garlic chive, leek, horseradish, red radish, and red cabbage tissues
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [121/1308] Searching PMID for: Varietal differences in the quercetin, kaempferol, and myricetin contents of highbush blueberry, cranberry, and thornless blackberry fruits
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [122/1308] Searching PMID for: Effect of domestic processing and cooking methods on phytic acid and polyphenol contents of pea cultivars (Pisum sativum)
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [123/1308] Searching PMID for: Effect of processing on nutritional and antinutritional factors of moongbean cultivars
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [124/1308] Searching PMID for: Biophenols in table olives
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [125/1308] Searching PMID for: Effect of processing on antioxidant contents in selected dry beans (Phaseolus spp. L.)
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [126/1308] Searching PMID for: Mangiferin and hesperidin metabolites are absorbed from the gastrointestinal tract of pigs after oral ingestion of a Cyclopia genistoides (honeybush tea) extract
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [127/1308] Searching PMID for: Tables on weight yield and nutrient retention factors for the calculation of nutrient composition of cooked foods (dishes)
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [128/1308] Searching PMID for: Disposition of soy isoflavones in normal human breast tissue
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [129/1308] Searching PMID for: Fast separation and determination of tyrosol, hydroxytyrosol and other phenolic compounds in extra-virgin olive oil by capillary zone electrophoresis with ultraviolet-diode array detection
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [130/1308] Searching PMID for: Antioxidant phenols in barley (Hordeum vulgare L.) flour: comparative spectrophotometric study among extraction methods of free and bound phenolic compounds
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [131/1308] Searching PMID for: Qualitative and semiquantitative analysis of phenolic compounds in extra virgin olive oils as a function of the ripening degree of olive fruits by different analytical techniques
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [132/1308] Searching PMID for: Phase I dose escalation pharmacokinetic study in healthy volunteers of resveratrol, a potential cancer chemopreventive agent
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [133/1308] Searching PMID for: Quantitation of trans-resveratrol and detection of its metabolites in human plasma and urine by high performance liquid chromatography
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [134/1308] Searching PMID for: The bioavailability of raspberry anthocyanins and ellagitannins in rats
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [135/1308] Searching PMID for: Bioavailability of multiple components following acute ingestion of a polyphenol-rich juice drink
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [136/1308] Searching PMID for: Antioxidant capacity and phenolic profile of table olives from the Greek market
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [137/1308] Searching PMID for: Changes in dietary fibre, phenolic acids and activity of endogenous enzymes during rye bread-making
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [138/1308] Searching PMID for: Identification and quantitation of ellagic acid in muscadine grape juice
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [139/1308] Searching PMID for: Anthocyanin composition of red raspberry juice: influences of cultivar, processing, and environmental factors
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [140/1308] Searching PMID for: Chemical composition and oxidative stability of flax, safflower and poppy seed and seed oils
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [141/1308] Searching PMID for: Avenanthramides in oats (Avena sativa) and structure-antioxidant activity relationships
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [142/1308] Searching PMID for: Absorption, conjugation and excretion of the flavanones, naringenin and hesperetin from alpha-rhamnosidase-treated orange juice in human subjects
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [143/1308] Searching PMID for: Rapid and complete extraction of phenols from olive oil and determination by means of a coulometric electrode array system
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [144/1308] Searching PMID for: Absorption, metabolism and excretion of flavanones from single portions of orange fruit and juice and effects of anthropometric variables and contraceptive pill use on flavanone excretion
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [145/1308] Searching PMID for: Method for determining the content of catechins in tea infusions by high-performance liquid chromatography
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [146/1308] Searching PMID for: Effect of domestic cooking on human bioavailability of naringenin, chlorogenic acid, lycopene and beta-carotene in cherry tomatoes
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [147/1308] Searching PMID for: Total and individual carotenoids and phenolic acids content in fresh, refrigerated and processed spinach (Spinacia oleracea L.)
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [148/1308] Searching PMID for: Phenolic compounds and their changes in apples during maturation and cold storage
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [149/1308] Searching PMID for: Quantification of free and protein-bound trans-resveratrol metabolites and identification of trans-resveratrol-C/O-conjugated diglucuronides - two novel resveratrol metabolites in human plasma
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [150/1308] Searching PMID for: Relationship among antioxidant activity, vasodilation capacity, and phenolic content of red wines
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [151/1308] Searching PMID for: Plant foods and herbal sources of resveratrol
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [152/1308] Searching PMID for: Additional studies on flavor components of corn tortilla chips
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [153/1308] Searching PMID for: Variation in tannin content in Vicia faba L
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [154/1308] Searching PMID for: Ingestion of red wine significantly increases plasma phenolic acid concentrations but does not acutely affect ex vivo lipoprotein oxidizability
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [155/1308] Searching PMID for: Tissue distribution in mice and metabolism in murine and human liver of apigenin and tricin, flavones with putative cancer chemopreventive properties
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [156/1308] Searching PMID for: Alkylperoxyl radical scavenging activity of red leaf lettuce (Lactuca sativa L.) phenolics
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [157/1308] Searching PMID for: Simultaneous determination of diosmin and diosmetin in human plasma by ion trap liquid chromatography-atmospheric pressure chemical ionization tandem mass spectrometry: Application to a clinical pharm
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [158/1308] Searching PMID for: Hydrophilic and lipophilic antioxidant activity in different leaves of three lettuce varieties
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [159/1308] Searching PMID for: Varietal differences among the polyphenol profiles of seven table grape cultivars studied by LC-DAD-MS-MS
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [160/1308] Searching PMID for: Anthocyanins are absorbed in glycated forms in elderly women: a pharmacokinetic study
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [161/1308] Searching PMID for: Antioxidant activity of fresh and dry herbs of some Lamiaceae species
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [162/1308] Searching PMID for: Phenolic compounds of virgin olive oil: influence of paste preparation techniques
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [163/1308] Searching PMID for: Levels of flavan-3-ols in French wines
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [164/1308] Searching PMID for: Electrophoretic identification and quantitation of compounds in the polyphenolic fraction of extra-virgin olive oil
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [165/1308] Searching PMID for: Phenolic composition and free radical scavenging activity of different apple varieties in relation to the cultivar, tissue type and storage
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [166/1308] Searching PMID for: Antioxidant activity in common beans (Phaseolus vulgaris L.)
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [167/1308] Searching PMID for: Characterisation of phenolic extracts from olive pulp and olive pomace by electrospray mass spectrometry
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [168/1308] Searching PMID for: Spectrophotometric and coulometric detection in the high-performance liquid chromatography of flavonoids and optimization of sample treatment for the determination of quercetin in orange juice
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [169/1308] Searching PMID for: Influence of organic versus conventional agricultural practice on the antioxidant microconstituent content of tomatoes and derived purees  consequences on antioxidant plasma status in humans
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [170/1308] Searching PMID for: Flavonoids detection by HPLC-DAD-MS-MS in lemon juices from Sicilian cultivars
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [171/1308] Searching PMID for: Anthocyanin excretion by humans increases linearly with increasing strawberry dose
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [172/1308] Searching PMID for: Identification of the flavonoid fraction in saffron spice by LC/DAD/MS/MS: Comparative study of samples from different geographical origins
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [173/1308] Searching PMID for: The aromatic and polyphenolic composition of lemon verbena tea
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [174/1308] Searching PMID for: Changes of flavonoids, vitamin C and antioxidant capacity in minimally processed citrus segments and juices during storage
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [175/1308] Searching PMID for: Effect of drying conditions and storage period on polyphenolic content, antioxidant capacity, and ascorbic acid of prunes
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [176/1308] Searching PMID for: Sensitive determination of phenolic acids in extra-virgin olive oil by capillary zone electrophoresis
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [177/1308] Searching PMID for: Co-electroosmotic capillary electrophoresis determination of phenolic acids in commercial olive oil
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [178/1308] Searching PMID for: Rapid quantification of the phenolic fraction of Spanish virgin olive oils by capillary electrophoresis with UV detection
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [179/1308] Searching PMID for: HPLC analysis of the benzoic and cinnamic acids in edible vegetable oils
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [180/1308] Searching PMID for: Urinary excretion of olive oil phenols and their metabolites in humans
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [181/1308] Searching PMID for: Effects of hyper-oxygenation and storage of Macabeo and Airén white wines on their phenolic and volatile composition
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [182/1308] Searching PMID for: Evaluation of the bioavailability and metabolism in the rat of punicalagin, an antioxidant polyphenol from pomegranate juice
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [183/1308] Searching PMID for: Repeated oral administration of high doses of the pomegranate ellagitannin punicalagin to rats for 37 days is not toxic
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [184/1308] Searching PMID for: The potent in vitro antioxidant ellagitannins from pomegranate juice are metabolised into bioavailable but poor antioxidant hydroxy-6H-dibenzopyran-6-one derivatives by the colonic microflora of healt
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [185/1308] Searching PMID for: Metabolism of antioxidant and chemopreventive ellagitannins from strawberries, raspberries, walnuts, and oak-aged wine in humans: Identification of biomarkers and individual variability
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [186/1308] Searching PMID for: Analytical comparison of monovarietal virgin olive oils obtained by both a continuous industrial plant and a low-scale mill
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [187/1308] Searching PMID for: Stoichiometric and kinetic studies of phenolic antioxidants from Andean purple corn and red-fleshed sweetpotato
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [188/1308] Searching PMID for: Development of an HPLC/diode-array detector method for simultaneous determination of 5-HMF, furfural, 5-o-caffeoylquinic acid and cafeine in coffee
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [189/1308] Searching PMID for: Phenolic composition of champagnes from Chardonnay and Pinot Noir vintages
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [190/1308] Searching PMID for: Isoflavonoid Content of Hong Kong Soy Foods
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [191/1308] Searching PMID for: Antioxidative potential of cashew phenolics in food and biological model systems as affected by roasting
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [192/1308] Searching PMID for: Low-density lipoprotein antioxidant activity of phenolic compounds and polyphenol oxidase activity in selected clingstone peach cultivars
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [193/1308] Searching PMID for: Identification of flavonoids in Hakmeitau beans (Vigna sinensis) by high-performance liquid chromatography-electrospray mass spectrometry (LC-ESI/MS)
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [194/1308] Searching PMID for: Detection of Conjugated Soy Metabolites in Urinary and Tissue Samples after Methanol Extraction
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [195/1308] Searching PMID for: Screening of antioxidant activity and antioxidant compounds of some edible plants of Thailand
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [196/1308] Searching PMID for: Total anthocyanins and total phenolics of fresh and processed cherries and their antioxidant properties
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [197/1308] Searching PMID for: Anthocyanin and polyphenolic composition of fresh and processed cherries
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [198/1308] Searching PMID for: effect of dose size on bioavailability of acylated and nonacylated anthocyanins from red cabbage (Brassica oleracea L. Var. capitata)
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [199/1308] Searching PMID for: Bioavailability of anthocyanins from purple carrot juice: effects of acylation and plant matrix
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [200/1308] Searching PMID for: Three-year comparison of the content of antioxidant microconstituents and several quality characteristics in organic and conventionally managed tomatoes and bell peppers
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [201/1308] Searching PMID for: Degradation of green tea catechins in tea drinks
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [202/1308] Searching PMID for: Separation and determination of flavonoids and other phenolic compounds in cranberry juice by high-performance liquid chromatography
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [203/1308] Searching PMID for: Alkylresorcinols as markers of whole grain wheat and rye in cereal products
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [204/1308] Searching PMID for: Pharmacokinetics and metabolism of the flavonoid scutellarin in humans after a single oral administration
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [205/1308] Searching PMID for: Quantitative determination of acetyl glucoside isoflavones and their metabolites in human urine using combined liquid chromatography-mass spectrometry
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [206/1308] Searching PMID for: Identification of metabolites of tectoridin in-vivo and in-vitro by liquid chromatography-tandem mass spectrometry
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [207/1308] Searching PMID for: Nutritional quality of black bean (Phaseolus) seeds
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [208/1308] Searching PMID for: Flavonoid glycosides and antioxidant capacity of various blackberry, blueberry and red grape genotypes determined by high-performance liquid chromatography/mass spectrometry
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [209/1308] Searching PMID for: Physicochemical and quality characteristics of cold-pressed flaxseed oils
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [210/1308] Searching PMID for: Novel approach to the detection and quantification of phenolic compounds in olive oil based on 31P nuclear magnetic resonance spectroscopy
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [211/1308] Searching PMID for: Flavonoid content of several vegetables and their antioxidant activity
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [212/1308] Searching PMID for: Antioxidant and antiproliferative activities of common vegetables
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [213/1308] Searching PMID for: Effect of cooking on the antioxidant properties of coloured peppers
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [214/1308] Searching PMID for: Changes in the phytochemical composition and profile of raw, boiled, and roasted peanuts
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [215/1308] Searching PMID for: Comparison of extraction methods for the quantification of selected phytochemicals in peanuts (Arachis hypogaea)
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [216/1308] Searching PMID for: Superoxide radical scavenging activity of the major polyphenols in fresh plums
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [217/1308] Searching PMID for: Contribution of individual polyphenolics to total antioxidant capacity of plums
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [218/1308] Searching PMID for: Consideration on equivalent chemicals in total phenolic assay of chlorogenic acid-rich plums
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [219/1308] Searching PMID for: Antioxidant properties of raw and processed cabbages
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [220/1308] Searching PMID for: Daily consumption of phenolics and total antioxidant capacity from fruit and vegetables in the American diet
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [221/1308] Searching PMID for: Contents of polyphenols in fruit and vegetables
# ...
# [1234/1308] Searching PMID for: Influence of cooking and dehulling on nutritional composition of several varieties of lentils (Lens culinaris)
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1235/1308] Searching PMID for: Pharmacokinetics of soybean isoflavones in plasma, urine and feces of men after ingestion of 60 g baked soybean powder (kinako)
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1236/1308] Searching PMID for: Solid-phase extraction and gas chromatography-mass spectrometry determination of kaempferol and quercetin in human urine after consumption of Ginkgo biloba tablets
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1237/1308] Searching PMID for: Phenolic acids in caryopses of two cultivars of wheat, rye and triticale that display different resistance to pre-harvest sprouting
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1238/1308] Searching PMID for: Changes in endogenous phenolic acids during development of Secale cereale caryopses and after dehydration treatment of unripe rye grains
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1239/1308] Searching PMID for: The contents of lignans in commercial sesame oils of Taiwan and their changes during heating
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1240/1308] Searching PMID for: Antioxidant properties of roasted coffee residues
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1241/1308] Searching PMID for: High-amylose corn exhibits better antioxidant activity than typical and waxy genotypes
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1242/1308] Searching PMID for: Identification and quantification of low molecular weight phenolic antioxidants in seeds of evening primrose (Oenothera biennis L.)
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1243/1308] Searching PMID for: Predictive analysis of cocoa procyanidins using near-infrared spectroscopy techniques
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1244/1308] Searching PMID for: Quercetin from shallots (Allium cepa L. var. aggregatum) is more bioavailable than its glucosides
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1245/1308] Searching PMID for: Ellagic acid content in strawberries of different cultivars and ripening stages
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1246/1308] Searching PMID for: Effects of fermentation and baking of whole wheat and whole rye sourdough breads on cereal alkylresorcinols
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1247/1308] Searching PMID for: Isoflavone aglycon and glucoconjugate content of high- and low-soy UK foods used in nutritional studies
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1248/1308] Searching PMID for: Influence of 10 wk of soy consumption on plasma concentrations and excretion of isoflavonoids and on gut microflora metabolism in healthy adults
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1249/1308] Searching PMID for: Antioxidant activity and phenolic compounds in 32 selected herbs
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1250/1308] Searching PMID for: Activities of amine and phenolic antioxidants and their changes in broad beans (Vicia faba) after freezing and steam cooking
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1251/1308] Searching PMID for: Influence of industrial sterilisation, freezing and steam cooking on antioxidant properties of green peas and string beans
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1252/1308] Searching PMID for: Studies on the dual antioxidant and antibacterial properties of parsley (Petroselinum crispum) and cilantro (Coriandrum sativum) extracts
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1253/1308] Searching PMID for: Absorption and metabolism of anthocyanins in elderly women after consumption of elderberry or blueberry
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1254/1308] Searching PMID for: Characterization of anthocyanins and proanthocyanidins in some cultivars of Ribes, Aronia, and Sambucus and their antioxidant capacity
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1255/1308] Searching PMID for: Pelargonidin is absorbed and metabolized differently than cyanidin after marionberry consumption in pigs
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1256/1308] Searching PMID for: Lipophilic and hydrophilic antioxidant capacities of common foods in the United States
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1257/1308] Searching PMID for: Aglycones and sugar moieties alter anthocyanin absorption and metabolism after berry consumption in weanling pigs
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1258/1308] Searching PMID for: Isolation and identification of ten metabolites of breviscapine in rat urine
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1259/1308] Searching PMID for: Pharmacokinetics of Naringin and its Metabolite Naringenin in Rats after Oral Administration of Rhizoma Drynariae Extract Assayed by UPLC-MS/MS
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1260/1308] Searching PMID for: Effects of soy isoflavones on estrogen and phytoestrogen metabolism in premenopausal women
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1261/1308] Searching PMID for: Soy consumption alters endogenous estrogen metabolism in postmenopausal women
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1262/1308] Searching PMID for: Epimerisation of tea polyphenols in tea drinks
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1263/1308] Searching PMID for: Absorption and metabolism of Astragali radix decoction: in silico, in vitro, and a case study in vivo
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1264/1308] Searching PMID for: Effect of soaking, boiling, and steaming on total phenolic content and antioxidant activities of cool season food legumes
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1265/1308] Searching PMID for: Total phenolic content and antioxidant properties of eclipse black beans (Phaseolus vulgaris L.) as affected by processing methods
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1266/1308] Searching PMID for: Phenolic Content, Composition, Antioxidant Activity, and Their Changes during Domestic Cooking of Potatoes
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1267/1308] Searching PMID for: Influence of polyphenol and ascorbate oxidases during cooking process on the radical-scavenging activity of vegetables
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1268/1308] Searching PMID for: Varietal differences in phenolic content and antioxidant and antiproliferative activities of onions
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1269/1308] Searching PMID for: Metabolic profile of 1,5-dicaffeoylquinic acid in rats, an in vivo and in vitro study
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1270/1308] Searching PMID for: Relative antioxidant and cytoprotective activities of common herbs
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1271/1308] Searching PMID for: Variations in the Composition of Various Acyl Lipids, Tocopherols and Lignans in Sesame Seed Oils Roasted in a Microwave-Oven
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1272/1308] Searching PMID for: Effects of seed roasting temperature and time on the quality characteristics of sesame (Sesamum indicum) oil
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1273/1308] Searching PMID for: Identification and quantification of metabolites of orally administered naringenin chalcone in rats
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1274/1308] Searching PMID for: Phytochemical phenolics in organically grown vegetables
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1275/1308] Searching PMID for: Changes in quality and phenolic compounds of virgin olive oils during objectively described fruit maturation
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1276/1308] Searching PMID for: Determination of isoflavones in soy products by capillary electrophoresis with electrochemical detection
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1277/1308] Searching PMID for: Analysis of phenolic acids in barley by high-performance liquid chromatography
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1278/1308] Searching PMID for: Antioxidant properties of cereal products
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1279/1308] Searching PMID for: Human, rat, and mouse metabolism of resveratrol
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1280/1308] Searching PMID for: Effect of broad bean and pea phenolics on the activity of lipase and lipoxygenase
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1281/1308] Searching PMID for: Phenolic acids of borage (Borago officinalis L.) and evening primrose (Oenothera biennis L.)
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1282/1308] Searching PMID for: Phenolic acid profiles in some small berries
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1283/1308] Searching PMID for: Effect of processing and storage on the antioxidant ellagic acid derivatives and flavonoids of red raspberry (Rubus idaeus) jams
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1284/1308] Searching PMID for: Changes during storage in conventional and ecological wine: Phenolic content and antioxidant activity
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1285/1308] Searching PMID for: Diagnostic performance of urinary resveratrol metabolites as a biomarker of moderate wine consumption
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1286/1308] Searching PMID for: Resveratrol metabolites in urine as a biomarker of wine intake in free-living subjects: The PREDIMED Study
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1287/1308] Searching PMID for: In vitro antioxidant activities of barley, husked oat, naked oat, triticale, and buckwheat wastes and their influence on the growth and biomarkers of antioxidant status in rats
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1288/1308] Searching PMID for: Inhibitory effect of jasmine green tea epicatechin isomers on LDL-oxidation
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1289/1308] Searching PMID for: Screening flavonoid metabolites of naringin and narirutin in urine after human consumption of grapefruit juice by LC-MS and LC-MS/MS
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1290/1308] Searching PMID for: GC-MS determination of flavonoids and phenolic and benzoic acids in human plasma after consumption of cranberry juice
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1291/1308] Searching PMID for: Phenolics, ascorbic acid, carotenoids and antioxidant activity of broccoli and their changes during conventional and microwave cooking
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1292/1308] Searching PMID for: Analysis of Isopropyl 3-(3,4- Dihydroxyphenyl)-2-hydroxypropanoate,a Metabolite of Danshensu, from Salvia miltiorrhiza, in Rabbit  plasma
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1293/1308] Searching PMID for: Metabolic analysis of four phenolic acids in rat by liquid chromatography-tandem mass spectrometry
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1294/1308] Searching PMID for: Identification of key metabolites of tectorigenin in rat urine by HPLC-MS(n)
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1295/1308] Searching PMID for: Changes of some chemical substances and antioxidant capacity of mandarin orange segments during can processing
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1296/1308] Searching PMID for: Phenolic antioxidants richly contained in corn bran are slightly bioavailable in rats
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1297/1308] Searching PMID for: Sesamin is one of the major precursors of mammalian lignans in sesame seed (Sesamum indicum) as observed in vitro and in rats
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1298/1308] Searching PMID for: Antioxidant activity and phenolic compounds in selected herbs
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1299/1308] Searching PMID for: Oxygen radical absorbing capacity of phenolics in blueberries, cranberries, chokeberries, and lingonberries
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1300/1308] Searching PMID for: Endogenous biophenol, fatty acid and volatile profiles of selected oils
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1301/1308] Searching PMID for: Direct analysis of trans-resveratrol in red wine by high performance liquid chromatography with chemiluminescent detection
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1302/1308] Searching PMID for: Reduced-oxidized glutathione status as a potential index of oxidative stress in mature cereal grain
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1303/1308] Searching PMID for: Antioxidant activity and total phenolics in selected cereal grains and their different morphological fractions
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1304/1308] Searching PMID for: Bioactive compounds in the cereal grains before and after hydrothermal processing
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1305/1308] Searching PMID for: Antioxidants in thermally treated buckwheat groats
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1306/1308] Searching PMID for: Effects of growing site and nitrogen fertilization on biomass production and lignan content of linseed (Linum usitatissimum L.)
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1307/1308] Searching PMID for: Separation, characterization and quantitation of benzoic and phenolic antioxidants in American cranberry fruit by GC-MS
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)
# [1308/1308] Searching PMID for: Variation in ferulic acid concentration among diverse barley cultivars measured by HPLC and microspectrophotometry
# > ERROR during request for article: Expecting value: line 1 column 1 (char 0)

# %%
print("Number of articles with PMID found:", ds_pmid['pmid'].notnull().sum())

# %%
# Step 2: Fetch article abstract by PMID
def fetch_abstract_by_pmid(pmid):
    params = {
        "db": "pubmed",
        "id": f"{pmid}",
        "retmode": "text",
        "rettype": "abstract",
    }

    try:
        response = requests.get(FETCH_URL, params=params)
        response.raise_for_status()
        print(f"> Fetched abstract!!")
        return response.text
    except requests.exceptions.RequestException as e:
        print(f"> ERROR fetching abstract for PMID '{pmid}': {e}")
        return None

ds_pmid_abstract = ds_pmid.copy()
for idx, article in ds_pmid_abstract.iterrows():
    pmid = article['pmid']
    if pd.notnull(pmid):
        print(f"[{idx + 1}/{len(ds_pmid_abstract)}] Fetching abstract for PMID: {pmid}")
        abstract = fetch_abstract_by_pmid(pmid)
        ds_pmid_abstract.at[idx, 'abstract'] = abstract
    else:
        print(f"[{idx + 1}/{len(ds_pmid_abstract)}] No PMID available, skipping abstract fetch.")
        ds_pmid_abstract.at[idx, 'abstract'] = None
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-555196369.py in <cell line: 0>()
#      23         return None
#      24
# ---> 25 ds_pmid_abstract = ds_pmid.copy()
#      26 for idx, article in ds_pmid_abstract.iterrows():
#      27     pmid = article['pmid']
#
# NameError: name 'ds_pmid' is not defined

# %%
ds_pmid_abstract.to_csv(PMID_ABSTRACTS, index=False)
print("Number of articles with abstract fetched:", ds_pmid_abstract['abstract'].notnull().sum())
print("Number of articles without abstract fetched:", ds_pmid_abstract['abstract'].isnull().sum())

# %%
def search_scopus(article_row, api_key):

    try:

        title = article_row.get('title', '').replace('"', '') # Remove quotes for query
        headers = {"Accept": "application/json"}
        params = {
            "query": f"TITLE-ABS-KEY(\"{title}\")",
            "apiKey": api_key
        }

        response = requests.get(ELSEVIER_SEARCH_URL,
                                headers=headers, params=params, timeout=10)
        response.raise_for_status()
        data = response.json()

        if 'search-results' in data and data['search-results']['entry']:
            try:
                return data['search-results']['entry'][0]['prism:url']
            except KeyError:
                return None
        return None

    except requests.exceptions.RequestException as e:
        print(f"> Scopus ERROR: {e}")

# %%
ds_elsevier = pd.read_csv(PMID_ABSTRACTS)

counters = {
    'total_missing': ds_elsevier['abstract'].isnull().sum(),
    'elsevier_found': 0,
    'failed': 0
}

for i, row in ds_elsevier.iterrows():

    if not pd.isnull(row['abstract']):
        continue

    print(f"[{i + 1}/{len(ds_elsevier)}] Searching ELSEVIER for abstract of article: {row['title']}")
    abstract_url = search_scopus(row, "3f5ff36eb8d1d409e3befea2ed2aa2cc")

    if abstract_url:
        response = requests.get(abstract_url,
                                headers={"Accept": "application/json",
                                         "X-ELS-APIKey": "3f5ff36eb8d1d409e3befea2ed2aa2cc"})
        if response.status_code == 200:
            data = response.json()
            try:
                abstract_text = data['abstracts-retrieval-response']['coredata']['dc:description']
                ds_elsevier.at[i, 'abstract'] = abstract_text
                print("> Found abstract via ELSEVIER!")
                counters['elsevier_found'] += 1
            except KeyError:
                print("> Abstract not found in ELSEVIER response.")
                counters['failed'] += 1
    else:
        print("> Nope :(")
        counters['failed'] += 1

    time.sleep(1) # Polite 1-second delay

ds_elsevier.to_csv(ELSEVIER_ABSTRACTS, index=False)
print("Summary of ELSEVIER abstract search:")
print(f"Total missing abstracts at start: {counters['total_missing']}")
print(f"Abstracts found via ELSEVIER: {counters['elsevier_found']}")
print(f"Failed attempts: {counters['failed']}")

# %% [markdown]
# TODO: ENCONTRAR LOS ~100 ARTÍCULOS QUE FALTAN @CRISTINA. SI NO A MANO. EL ULTIMO CSV ES "publications_abstract_pubmed_elsevier.csv", PARTIR DE AHÍ.
#
# LUEGO EL RESTO DE CODIGO DEBERÍA FUNCIONAR BIEN AUNQUE HAY QUE CAMBIAR EL DATASET FINAL Y ALGUNAS VARIABLES. SINO PREGUNTAR A @DIDIER.

# %%
import os

# --- Configuración ---

# Este es el archivo final después de intentar PubMed y Elsevier (mencionado en la celda TODO)
FINAL_DATASET_FILE = 'publications_abstract_pubmed_elsevier.csv'

# Nombre del archivo de salida para los artículos sin abstract
OUTPUT_FILE = 'documentos_sin_abstract.csv'

# ---------------------

print(f"Buscando el archivo: {FINAL_DATASET_FILE}...")

if os.path.exists(FINAL_DATASET_FILE):
    print(f"Archivo encontrado. Cargando datos...")

    try:
        # Cargar el dataset que contiene los resultados de todos los intentos de búsqueda
        final_df = pd.read_csv(FINAL_DATASET_FILE)

        print(f"Datos cargados. Total de artículos: {len(final_df)}")

        # Filtrar para encontrar las filas donde la columna 'abstract' sigue estando vacía (NaN)
        missing_abstracts_df = final_df[final_df['abstract'].isnull()]

        num_missing = len(missing_abstracts_df)

        if num_missing > 0:
            print(f"Se encontraron {num_missing} documentos a los que les falta el abstract.")

            # Guardar estos documentos (con toda su información) en un nuevo CSV
            missing_abstracts_df.to_csv(OUTPUT_FILE, index=False, encoding='utf-8')

            print(f"¡Éxito! Se han guardado los {num_missing} documentos en el archivo: {OUTPUT_FILE}")

            # Opcional: Muestra los primeros 5 artículos encontrados
            print("\nPrimeros 5 artículos sin abstract:")
            print(missing_abstracts_df.head())
        else:
            print("¡Enhorabuena! No se encontraron documentos con abstracts faltantes en el archivo.")

    except Exception as e:
        print(f"Ocurrió un error al procesar el archivo: {e}")

else:
    print(f"Error: No se pudo encontrar el archivo '{FINAL_DATASET_FILE}'.")
    print("Por favor, asegúrate de haber ejecutado las celdas anteriores del notebook (Tasks 1, incluyendo la búsqueda en PubMed y Elsevier) para generar este archivo.")
# Out:
# Buscando el archivo: publications_abstract_pubmed_elsevier.csv...
# Archivo encontrado. Cargando datos...
# Datos cargados. Total de artículos: 1308
# Se encontraron 105 documentos a los que les falta el abstract.
# ¡Éxito! Se han guardado los 105 documentos en el archivo: documentos_sin_abstract.csv
#
# Primeros 5 artículos sin abstract:
#       id                                            authors  \
# 33   167                  Amiot M.J., Aubert S., Nicolas J.
# 46   584  Aparicio-Fernandez X., Manzo-Bonilla L., Loarc...
# 49   143                 Arena E., Fallico B., Maccarone E.
# 96   104                                 Bassi D., Selli R.
# 102  115              Begona Barroso, M.  Werken van de, G.
#
#     year_of_publication                                              title  \
# 33                 1993  Phenolic composition and browning susceptibili...
# 46                 2005  Comparison of antimutagenic activity of phenol...
# 49                 2001  Evaluation of the antioxidant capacity of bloo...
# 96                 1990   Evaluation of fruit quality in peach and apricot
# 102                1999  Determination of green and black tea compositi...
#
#                 abbreviation                               journal_name  \
# 33                AMIOT 1993                         Acta Horticulturae
# 46   APARICIO-FERNANDEZ 2005                    Journal of Food Science
# 49                ARENA 2001                             Food Chemistry
# 96                BASSI 1990          Advances in Horticultural Science
# 102      BEGONA BARROSO 1999  Journal of High Resolution Chromatography
#
#     journal_volume journal_issue    pages               created_at  \
# 33             343           NaN    67-69  2015-04-13 21:45:23 UTC
# 46              70             1  S73-S78  2007-12-04 11:45:05 UTC
# 49              74             4  423-427  2015-04-13 21:45:23 UTC
# 96               4           NaN  107-112  2003-12-05 10:41:49 UTC
# 102             22             4  225-230  2015-04-13 21:45:23 UTC
#
#                   updated_at        pmid abstract
# 33   2015-04-13 21:45:23 UTC         NaN      NaN
# 46   2015-04-13 21:45:26 UTC         NaN      NaN
# 49   2015-04-13 21:45:23 UTC         NaN      NaN
# 96   2015-04-14 04:26:17 UTC         NaN      NaN
# 102   2015-04-14 04:26:20 UTC        NaN      NaN

# %% [markdown]
# ## **Task 2:**
#
# Use the EUtilities tool to search for articles whose content is not relevant to this task. Size of the dataset should be the same of relevant documents.

# %%
def get_articles_pmids_for_title(title, count, api_key=None):

    params = {
        "db": "pubmed",
        "term": f"{title}[Title]",
        "retmode": "json",
        "retmax": count,
        "api_key": api_key
    }

    try:
        response = requests.get(ESEARCH_URL, params=params)
        response.raise_for_status()
        data = response.json()

        if 'esearchresult' in data and data['esearchresult']['count'] != '0':
            return data['esearchresult']['idlist']
        else:
            print(f"Found {data['esearchresult']['count']} irrelevant articles.")
            return []

    except requests.exceptions.RequestException as e:
        print(f"Error during request for irrelevant articles: {e}")
        return []

# %%
IRRELEVANT_PUBLICATIONS = 'irrelevant_publications.csv'

final_df = pd.read_csv('publications_abstract_pubmed_elsevier.csv')

irrelevant_pmids_list = get_articles_pmids_for_title("cancer", len(final_df))

irrelevant_abstracts = []
for pmid in irrelevant_pmids_list:

    article_info = {
        'pmid': pmid,
        'abstract': None
    }

    article_info['abstract'] = fetch_abstract_by_pmid(pmid)
    irrelevant_abstracts.append(article_info)

    # CHANGE ME TO 0.1 IF YOU HAVE AN API KEY
    print("Sleeping for 0.1...")
    time.sleep(0.1)  # Delaying 0.1s to respect NCBI rate limits (3 requests per second)

# Save irrelevant abstracts to a new dataset
irrelevant_df = pd.DataFrame(irrelevant_abstracts)
irrelevant_df.to_csv(IRRELEVANT_PUBLICATIONS, index=False)
# Out:
# Error during request for irrelevant articles: Expecting value: line 1 column 1 (char 0)

# %%
irrelevant_df

# %% [markdown]
# ## **Task 4:**
#
# Implement the chosen retrieval system using the programming language of their choice. If the information retrieval system is based on machine learning techniques, the student must split the existing datasets (relevant and non-relevant documents) into three distinct groups (training, validation, and testing) to carry out the model training.

# %% [markdown]
# **CHOSEN RETRIEVAL SYSTEM:** BioBERT-based Binary Text Classifier

# %%
# Adding target variable 'relevance'
relevant_df['relevance'] = 1
irrelevant_df['relevance'] = 0

# Combining relevant and irrelevant datasets and maintaining only abstract and relevance columns
features = ['abstract', 'relevance']
combined_df = pd.concat([relevant_df[features], irrelevant_df[features]], ignore_index=True)

# Remove any rows where the abstract is missing (e.g., API fetch failed)
combined_df.dropna(subset=['abstract'], inplace=True)
combined_df.reset_index(drop=True, inplace=True)

# Saving
combined_df.to_csv('combined_publications.csv', index=False)

print("Class distribution:")
print(combined_df['relevance'].value_counts())

combined_df

# %% [markdown]
# Following Fine-tuning of BERT for text classification tasks: https://huggingface.co/docs/transformers/en/tasks/sequence_classification

# %% [markdown]
# - Train-Test-Validation Split: 80%-10%-10%

# %%
RANDOM_STATE = 42

train_df, test_df = train_test_split(combined_df,
                                     test_size=0.2,
                                     stratify=combined_df["relevance"],
                                     random_state=RANDOM_STATE)

val_df, test_df = train_test_split(test_df,
                                   test_size=0.5,
                                   stratify=test_df["relevance"],
                                   random_state=RANDOM_STATE)

print(f"Training size: {len(train_df)}")
print(f"Validation size: {len(val_df)}")
print(f"Test size: {len(test_df)}")

# %% [markdown]
# - Convert Pandas DataFrame to HuggingFace Dataset

# %%
train_dataset = Dataset.from_pandas(train_df)
val_dataset = Dataset.from_pandas(val_df)
test_dataset = Dataset.from_pandas(test_df)

# %% [markdown]
# - Tokenization of abstracts using BioBERT tokenizer

# %%
BERT_MODEL_NAME = "dmis-lab/biobert-v1.1"
tokenizer = AutoTokenizer.from_pretrained(BERT_MODEL_NAME)

def tokenize(examples):
    return tokenizer(examples["abstract"],
                     padding="max_length",
                     truncation=True,
                     max_length=512 # Maximum length for BERT models
                    )

train_dataset = train_dataset.map(tokenize, batched=True)
val_dataset = val_dataset.map(tokenize, batched=True)
test_dataset = test_dataset.map(tokenize, batched=True)

# Renaming the target column to 'labels' as expected by HuggingFace Trainer
train_dataset = train_dataset.rename_column("relevance", "labels")
val_dataset = val_dataset.rename_column("relevance", "labels")
test_dataset = test_dataset.rename_column("relevance", "labels")

# %% [markdown]
# - Loading BioBERT model for binary text classification (relevant vs irrelevant)

# %%
id2label = {0: "irrelevant", 1: "relevant"}
label2id = {"irrelevant": 0, "relevant": 1}

model = AutoModelForSequenceClassification.from_pretrained(BERT_MODEL_NAME,
                                                           num_labels=2,
                                                           id2label=id2label,
                                                           label2id=label2id)

# %% [markdown]
# - Defining evaluation metrics

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_recall_fscore_support,
    roc_auc_score
)
import numpy as np

# ---- For ranked results ----

def precision_at_k(y_true, y_score, k):
    order = np.argsort(y_score)[::-1]
    y_true_sorted = np.array(y_true)[order]
    top_k = y_true_sorted[:k]
    return np.mean(top_k)

def r_precision(y_true, y_score):
    R = int(np.sum(y_true))
    return precision_at_k(y_true, y_score, R) if R > 0 else 0

def average_precision(y_true, y_score):
    order = np.argsort(y_score)[::-1]
    y_true_sorted = np.array(y_true)[order]
    precisions = []
    relevant = 0
    for i, val in enumerate(y_true_sorted, start=1):
        if val == 1:
            relevant += 1
            precisions.append(relevant / i)
    return np.mean(precisions) if precisions else 0

def reciprocal_rank(y_true, y_score):
    order = np.argsort(y_score)[::-1]
    y_true_sorted = np.array(y_true)[order]
    for i, val in enumerate(y_true_sorted, start=1):
        if val == 1:
            return 1 / i
    return 0

def f_measure(precision, recall, beta=1.0):
    return (1 + beta**2) * (precision * recall) / (beta**2 * precision + recall) if (precision + recall) else 0


# ---- metrics ----

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    probs = logits[:, 1]  # positive class probability
    predictions = np.argmax(logits, axis=-1)

    accuracy = accuracy_score(labels, predictions)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, predictions, average="binary", zero_division=0)

    # IR Metrics
    p_at_5 = precision_at_k(labels, probs, 5)
    p_at_10 = precision_at_k(labels, probs, 10)
    r_prec = r_precision(labels, probs)
    avg_prec = average_precision(labels, probs)
    rr = reciprocal_rank(labels, probs)
    auroc = roc_auc_score(labels, probs)
    f_beta_2 = f_measure(precision, recall, beta=2.0)  # example

    return {
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1": f1,
        "F2": f_beta_2,
        "AUROC": auroc,
        "P@5": p_at_5,
        "P@10": p_at_10,
        "R-Precision": r_prec,
        "AvgPrecision": avg_prec,
        "ReciprocalRank": rr
    }

# %% [markdown]
# - Putting the training arguments

# %%
training_args = TrainingArguments(
    output_dir="./biobert_pubmed_classifier",

    # Training hyperparameters
    num_train_epochs=3,
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,

    # Optimiser settings
    weight_decay=0.01,

    # Evaluation settings
    evaluation_strategy="epoch",
    save_strategy="epoch",
    logging_steps=100,

    # Model selection
    load_best_model_at_end=True,
    metric_for_best_model="f1",
    greater_is_better=True,

    # Performance
    fp16=torch.cuda.is_available(),
    dataloader_num_workers=4,

    seed=RANDOM_STATE,
    push_to_hub=False,
    report_to="none"
)

# %% [markdown]
# - Actual training using Trainer API

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=2)]
)

trainer.train()

# %% [markdown]
# - Evaluating on the test set

# %%
predictions_output = trainer.predict(test_dataset)
predictions = np.argmax(predictions_output.predictions, axis=-1)
true_labels = predictions_output.label_ids

# Calculate all metrics
test_metrics = compute_metrics((predictions_output.predictions, true_labels))

print("\nTest Set Results:")
print(f"Accuracy:  {test_metrics['accuracy']:.4f}")
print(f"Precision: {test_metrics['precision']:.4f}")
print(f"Recall:    {test_metrics['recall']:.4f}")
print(f"F1-Score:  {test_metrics['f1']:.4f}")

print("\n Ranked Results:")
print(f"AUROC:          {test_metrics['AUROC']:.4f}")
print(f"P@5:            {test_metrics['P@5']:.4f}")
print(f"P@10:           {test_metrics['P@10']:.4f}")
print(f"R-Precision:    {test_metrics['R-Precision']:.4f}")
print(f"Avg Precision:  {test_metrics['AvgPrecision']:.4f}")
print(f"ReciprocalRank: {test_metrics['ReciprocalRank']:.4f}")

# Detailed classification report
print("\nClassification Report:")
print(classification_report(
    true_labels,
    predictions,
    target_names=['Irrelevant', 'Relevant'],
    digits=4
))

# Confusion matrix
print("\nConfusion Matrix:")
cm = confusion_matrix(true_labels, predictions)
print(cm)
print(f"\nTrue Negatives:  {cm[0][0]} (correctly identified irrelevant)")
print(f"False Positives: {cm[0][1]} (incorrectly marked relevant)")
print(f"False Negatives: {cm[1][0]} (missed relevant papers)")
print(f"True Positives:  {cm[1][1]} (correctly identified relevant)")

# %% [markdown]
# - saving the trained model

# %%
model_save_path = './final_biobert_classifier'
trainer.save_model(model_save_path)
tokenizer.save_pretrained(model_save_path)
